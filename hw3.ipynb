# %%
pip install owlready2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting owlready2
#   Downloading owlready2-0.47.tar.gz (27.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.3/27.3 MB 221.2 kB/s eta 0:00:0000:0100:04
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: owlready2
#   Building wheel for owlready2 (pyproject.toml) ... done
#   Created wheel for owlready2: filename=owlready2-0.47-cp39-cp39-macosx_10_9_universal2.whl size=23106154 sha256=3e750c5c10d03c04a94ef860a71dd6ee92f39e7f3b76ca586d42ea9052e2e70b
#   Stored in directory: /Users/gokcesoylu/Library/Caches/pip/wheels/b1/00/80/7bbc71431038291ed5edcea03194902854c7cb6775edd9f8f5
# Successfully built owlready2
# Installing collected packages: owlready2
# Successfully installed owlready2-0.47
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: /Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from owlready2 import *

# OWL dosyasını yükle
onto = get_ontology("/Users/gokcesoylu/ontology_engineering/hw3.owl").load()

# Ontolojideki sınıfları yazdır
print(list(onto.classes()))
# Out:
# [ex.Event, ex.Location, ex.Time, ex.Participant, ex.Organizer]
